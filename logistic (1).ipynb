# %% [markdown]
# #**Philip George Varughese**
# # **21BAI1623**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression

# %%
# Generate synthetic data
X, y = make_classification(n_samples=100, n_features=2, n_informative=2, n_redundant=0, random_state=42)

# %%
# Fit logistic regression model
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
# Predict class labels and probabilities
y_pred = model.predict(X)
y_prob = model.predict_proba(X)

# %%
# Plot the decision boundary
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
h = 0.02  # step size for meshgrid
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.figure()
plt.contourf(xx, yy, Z, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Logistic Regression Decision Boundary')
# Out:
# Text(0.5, 1.0, 'Logistic Regression Decision Boundary')

# %%
# Print class labels and probabilities
for i, (pred, prob) in enumerate(zip(y_pred, y_prob)):
    print(f"Data point {i+1}: Predicted class = {pred}, Probabilities = {prob}")

plt.show()
# Out:
# Data point 1: Predicted class = 0, Probabilities = [0.54022246 0.45977754]
# Data point 2: Predicted class = 1, Probabilities = [0.00739431 0.99260569]
# Data point 3: Predicted class = 0, Probabilities = [0.96648385 0.03351615]
# Data point 4: Predicted class = 0, Probabilities = [9.99258825e-01 7.41174556e-04]
# Data point 5: Predicted class = 1, Probabilities = [0.00424354 0.99575646]
# Data point 6: Predicted class = 0, Probabilities = [0.97268498 0.02731502]
# Data point 7: Predicted class = 1, Probabilities = [0.2525352 0.7474648]
# Data point 8: Predicted class = 1, Probabilities = [0.24231794 0.75768206]
# Data point 9: Predicted class = 0, Probabilities = [0.94147139 0.05852861]
# Data point 10: Predicted class = 1, Probabilities = [0.08378794 0.91621206]
# Data point 11: Predicted class = 1, Probabilities = [2.69179177e-04 9.99730821e-01]
# Data point 12: Predicted class = 0, Probabilities = [0.53404893 0.46595107]
# Data point 13: Predicted class = 0, Probabilities = [0.93903122 0.06096878]
# Data point 14: Predicted class = 1, Probabilities = [0.07681624 0.92318376]
# Data point 15: Predicted class = 1, Probabilities = [0.00335082 0.99664918]
# Data point 16: Predicted class = 0, Probabilities = [0.95970748 0.04029252]
# Data point 17: Predicted class = 1, Probabilities = [0.01374666 0.98625334]
# Data point 18: Predicted class = 0, Probabilities = [0.88221352 0.11778648]
# Data point 19: Predicted class = 1, Probabilities = [0.00523209 0.99476791]
# Data point 20: Predicted class = 0, Probabilities = [9.99017630e-01 9.82370185e-04]
# Data point 21: Predicted class = 1, Probabilities = [0.027356 0.972644]
# Data point 22: Predicted class = 0, Probabilities = [0.58289508 0.41710492]
# Data point 23: Predicted class = 0, Probabilities = [0.9613687 0.0386313]
# Data point 24: Predicted class = 0, Probabilities = [9.99651088e-01 3.48912188e-04]
# Data point 25: Predicted class = 1, Probabilities = [0.02626367 0.97373633]
# Data point 26: Predicted class = 0, Probabilities = [0.56323226 0.43676774]
# Data point 27: Predicted class = 1, Probabilities = [0.03901484 0.96098516]
# Data point 28: Predicted class = 1, Probabilities = [0.0030851 0.9969149]
# Data point 29: Predicted class = 1, Probabilities = [0.04215859 0.95784141]
# Data point 30: Predicted class = 1, Probabilities = [0.32229976 0.67770024]
# Data point 31: Predicted class = 0, Probabilities = [0.84431834 0.15568166]
# Data point 32: Predicted class = 0, Probabilities = [0.98864167 0.01135833]
# Data point 33: Predicted class = 0, Probabilities = [0.99857237 0.00142763]
# Data point 34: Predicted class = 0, Probabilities = [0.98163958 0.01836042]
# Data point 35: Predicted class = 1, Probabilities = [0.04318446 0.95681554]
# Data point 36: Predicted class = 1, Probabilities = [0.06310805 0.93689195]
# Data point 37: Predicted class = 0, Probabilities = [0.99799297 0.00200703]
# Data point 38: Predicted class = 0, Probabilities = [0.98066544 0.01933456]
# Data point 39: Predicted class = 0, Probabilities = [0.94106713 0.05893287]
# Data point 40: Predicted class = 0, Probabilities = [0.77022508 0.22977492]
# Data point 41: Predicted class = 1, Probabilities = [0.35872553 0.64127447]
# Data point 42: Predicted class = 1, Probabilities = [0.05141027 0.94858973]
# Data point 43: Predicted class = 0, Probabilities = [0.94501164 0.05498836]
# Data point 44: Predicted class = 1, Probabilities = [0.20062964 0.79937036]
# Data point 45: Predicted class = 1, Probabilities = [0.01236779 0.98763221]
# Data point 46: Predicted class = 0, Probabilities = [0.95367018 0.04632982]
# Data point 47: Predicted class = 1, Probabilities = [0.02238558 0.97761442]
# Data point 48: Predicted class = 1, Probabilities = [0.14911836 0.85088164]
# Data point 49: Predicted class = 1, Probabilities = [0.00418962 0.99581038]
# Data point 50: Predicted class = 1, Probabilities = [0.02681966 0.97318034]
# Data point 51: Predicted class = 0, Probabilities = [0.9964225 0.0035775]
# Data point 52: Predicted class = 1, Probabilities = [0.18968285 0.81031715]
# Data point 53: Predicted class = 1, Probabilities = [0.05032647 0.94967353]
# Data point 54: Predicted class = 1, Probabilities = [0.07288356 0.92711644]
# Data point 55: Predicted class = 0, Probabilities = [0.97849344 0.02150656]
# Data point 56: Predicted class = 0, Probabilities = [0.97677784 0.02322216]
# Data point 57: Predicted class = 0, Probabilities = [0.91271499 0.08728501]
# Data point 58: Predicted class = 1, Probabilities = [0.058543 0.941457]
# Data point 59: Predicted class = 0, Probabilities = [0.90345394 0.09654606]
# Data point 60: Predicted class = 0, Probabilities = [0.98739724 0.01260276]
# Data point 61: Predicted class = 0, Probabilities = [0.74646837 0.25353163]
# Data point 62: Predicted class = 1, Probabilities = [0.01195861 0.98804139]
# Data point 63: Predicted class = 1, Probabilities = [0.09377604 0.90622396]
# Data point 64: Predicted class = 1, Probabilities = [0.33853091 0.66146909]
# Data point 65: Predicted class = 0, Probabilities = [0.99117932 0.00882068]
# Data point 66: Predicted class = 1, Probabilities = [0.01238663 0.98761337]
# Data point 67: Predicted class = 0, Probabilities = [0.95062458 0.04937542]
# Data point 68: Predicted class = 0, Probabilities = [9.99340992e-01 6.59007844e-04]
# Data point 69: Predicted class = 0, Probabilities = [0.91654958 0.08345042]
# Data point 70: Predicted class = 1, Probabilities = [0.03839121 0.96160879]
# Data point 71: Predicted class = 1, Probabilities = [0.0205278 0.9794722]
# Data point 72: Predicted class = 0, Probabilities = [0.98295428 0.01704572]
# Data point 73: Predicted class = 0, Probabilities = [0.98348581 0.01651419]
# Data point 74: Predicted class = 1, Probabilities = [0.01714499 0.98285501]
# Data point 75: Predicted class = 1, Probabilities = [0.02837235 0.97162765]
# Data point 76: Predicted class = 0, Probabilities = [0.96703676 0.03296324]
# Data point 77: Predicted class = 1, Probabilities = [0.00542374 0.99457626]
# Data point 78: Predicted class = 1, Probabilities = [0.00302344 0.99697656]
# Data point 79: Predicted class = 0, Probabilities = [0.9385464 0.0614536]
# Data point 80: Predicted class = 0, Probabilities = [0.9706296 0.0293704]
# Data point 81: Predicted class = 0, Probabilities = [0.9749751 0.0250249]
# Data point 82: Predicted class = 1, Probabilities = [0.00152133 0.99847867]
# Data point 83: Predicted class = 0, Probabilities = [0.75721902 0.24278098]
# Data point 84: Predicted class = 0, Probabilities = [0.98779861 0.01220139]
# Data point 85: Predicted class = 1, Probabilities = [0.00137715 0.99862285]
# Data point 86: Predicted class = 1, Probabilities = [0.15613348 0.84386652]
# Data point 87: Predicted class = 1, Probabilities = [0.03061757 0.96938243]
# Data point 88: Predicted class = 1, Probabilities = [0.01489458 0.98510542]
# Data point 89: Predicted class = 0, Probabilities = [0.99765281 0.00234719]
# Data point 90: Predicted class = 0, Probabilities = [0.84891386 0.15108614]
# Data point 91: Predicted class = 0, Probabilities = [0.97072236 0.02927764]
# Data point 92: Predicted class = 0, Probabilities = [0.98950001 0.01049999]
# Data point 93: Predicted class = 1, Probabilities = [0.02725049 0.97274951]
# Data point 94: Predicted class = 0, Probabilities = [0.81601801 0.18398199]
# Data point 95: Predicted class = 1, Probabilities = [0.00878137 0.99121863]
# Data point 96: Predicted class = 1, Probabilities = [0.00244402 0.99755598]
# Data point 97: Predicted class = 1, Probabilities = [0.01003085 0.98996915]
# Data point 98: Predicted class = 0, Probabilities = [0.95070523 0.04929477]
# Data point 99: Predicted class = 0, Probabilities = [0.98815466 0.01184534]
# Data point 100: Predicted class = 0, Probabilities = [0.99733867 0.00266133]
